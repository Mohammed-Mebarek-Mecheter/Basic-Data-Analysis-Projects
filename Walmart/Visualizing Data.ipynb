# %%
# Import relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import ggplot, aes, geom_bar, scale_x_discrete, theme

# %%
# Load dataset
walmart_data = pd.read_csv("data/Walmart.csv")
walmart_data.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1    5/2/2010    1643690.90             0        42.31       2.572
# 1      1   12/2/2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1    5/3/2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
walmart_data_sorted = walmart_data.sort_values('Weekly_Sales', ascending = False)
walmart_data_sorted
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1905     14  24-12-2010    3818686.45             0        30.59       3.141
# 2763     20  24-12-2010    3766687.43             0        25.17       3.141
# 1333     10  24-12-2010    3749057.69             0        57.06       3.236
# 527       4  23-12-2011    3676388.98             0        35.92       3.103
# 1762     13  24-12-2010    3595903.20             0        34.90       2.846
# ...     ...         ...           ...           ...          ...         ...
# 4671     33   2/12/2011     220060.35             0        59.12       3.701
# 4623     33  31-12-2010     219804.85             1        52.91       3.148
# 4675     33  30-12-2011     215359.21             1        51.60       3.428
# 4614     33  29-10-2010     213538.32             0        71.34       3.130
# 4619     33   3/12/2010     209986.25             0        52.82       3.041
#
#              CPI  Unemployment
# ...

# %% [markdown]
# ### Plot a bar chart using Matplotlib

# %%
plt.figure(figsize=(12, 6))

x = walmart_data_sorted['Store'][0:10]
y = walmart_data_sorted['Weekly_Sales'][0:10]

plt.bar(x, y)
plt.xlabel('Store', fontsize=12)
plt.ylabel('Weekly Sales', fontsize=12)
plt.title('Top 10 Stores with the Highest Weekly Sales', fontsize=15)

# Set specific x-axis tick positions using set_xticks
plt.xticks(walmart_data_sorted['Store'][0:10], fontsize=10)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Create Subplots

# %%
# Get data for the top 10 stores
top_stores_data = walmart_data_sorted.head(10)

fig, ax = plt.subplots(figsize=(40, 18), ncols=2)

# First subplot
ax[0].bar(top_stores_data['Store'], top_stores_data['Weekly_Sales'])
ax[0].set_xticks(top_stores_data['Store'])
ax[0].set_xlabel('Store', fontsize=25)
ax[0].set_ylabel('Weekly sales in millions', fontsize=25)
ax[0].set_title('Top 10 Stores with the Highest Weekly Sales', fontsize=25)
ax[0].tick_params(axis='both', labelsize=20)

# Second subplot
ax[1].bar(top_stores_data['Store'], top_stores_data['Temperature'])
ax[1].set_xticks(top_stores_data['Store'])
ax[1].set_xlabel('Store', fontsize=25)
ax[1].set_ylabel('Temperature', fontsize=25)
ax[1].set_title('Top 10 Stores with the Highest Weekly Sales per Temperature', fontsize=25)
ax[1].tick_params(axis='both', labelsize=20)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(12, 6))

data = walmart_data_sorted.head(10)  # Get the top 10 stores

sns.barplot(data=data, x='Store', y='Weekly_Sales')  # Use the correct column name 'Weekly_Sales'

plt.xlabel('Store', fontsize=13)
plt.ylabel('Weekly Sales in millions', fontsize=13)
plt.title('Top 10 Stores with the Highest Weekly Sales', fontsize=15)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

plt.tight_layout()

plt.show()

# %%
chart_data = walmart_data_sorted.head(10)  # Get the top 10 stores

(
        ggplot(chart_data) +
        aes(x='Store', y='Weekly_Sales') +
        geom_bar(stat='identity') +
        scale_x_discrete(limits=chart_data['Store'].tolist()) +
        theme(figure_size=(16, 8))
)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fc236561-f552-46d2-9d61-d0f3554d0303">Loading BokehJS ...</span>
#     </div>
#   <div id="ba80c386-5122-4384-af0d-a8a2a687119a" data-root-id="p1641" style="display: contents;"></div>
