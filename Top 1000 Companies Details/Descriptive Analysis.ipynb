# %%
# Import relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data
companies_data = pd.read_csv("data/Top_1000_Companies_Dataset.csv")

# %%
companies_data.head()
# Out:
#           company_name          url           city state        country  \
# 0               OpenAI   openai.com  San Francisco    CA  United States
# 1              Alchemy  alchemy.com  San Francisco    CA  United States
# 2             dbt Labs   getdbt.com   Philadelphia    PA  United States
# 3  Wasabi Technologies   wasabi.com         Boston    MA  United States
# 4              Whatnot  whatnot.com    Los Angeles    CA  United States
#
#    employees                                       linkedin_url  founded  \
# 0        655             http://www.linkedin.com/company/openai   2015.0
# 1        201         http://www.linkedin.com/company/alchemyinc      NaN
# 2        511            http://www.linkedin.com/company/dbtlabs   2016.0
# 3        355  http://www.linkedin.com/company/wasabitechnolo...   2017.0
# 4        551        http://www.linkedin.com/company/whatnot-inc   2019.0
#
#     Industry  GrowjoRanking  ...  \
# 0         AI              1  ...
# ...

# %%
# Check unique values and their counts in the 'Industry' column
industry_distribution = companies_data['Industry'].value_counts()

# Display the distribution of companies across industries
industry_distribution
# Out:
# Fintech            167
# Tech Services      120
# AI                  42
# Analytics           42
# IT Security         37
#                   ...
# Cloud                1
# Pharmaceuticals      1
# Consumer             1
# Farming              1
# Veterinary           1
# Name: Industry, Length: 120, dtype: int64

# %%
# Calculate the top 10 industries by count
top_industries = companies_data['Industry'].value_counts().head(10)
top_industries
# Out:
# Fintech                167
# Tech Services          120
# AI                      42
# Analytics               42
# IT Security             37
# Digital Health          34
# Finance                 28
# Environmental           24
# Hospital/Healthcare     17
# Food                    17
# Name: Industry, dtype: int64

# %%
# Set up plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_industries.values, y=top_industries.index, palette='viridis')

# Add labels and title
plt.xlabel('Number of Companies')
plt.ylabel('Industry')
plt.title('Top 10 Industries by Company Count')

# Show the plot
plt.show()

# %%
# Check unique values and their counts in the 'country' column
country_representation = companies_data['country'].value_counts()

# Display the representation of countries in the dataset
country_representation
# Out:
# United States           771
# United Kingdom           48
# India                    37
# Canada                   27
# Germany                  14
# Israel                   11
# France                    9
# Australia                 9
# Norway                    6
# Singapore                 5
# Sweden                    5
# Netherlands               4
# Switzerland               4
# Mexico                    4
# Hong Kong                 3
# Finland                   3
# South Africa              2
# Ireland                   2
# Australiatria             2
# Italy                     2
# South Korea               2
# Spain                     2
# United State              2
# Poland                    1
# Turkey                    1
# Netharlands               1
# Taiwan                    1
# Cyprus                    1
# Thailand                  1
# Romania                   1
# Namibia                   1
# Lithuania                 1
# Kuwait                    1
# ...

# %%
# Calculate the top 10 countries by count
top_countries = country_representation.head(10)

# Set up plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_countries.values, y=top_countries.index, palette='viridis')

# Add labels and title
plt.xlabel('Number of Companies')
plt.ylabel('Country')
plt.title('Top 10 Countries with Highest Representation')

# Show the plot
plt.show()

# %%
# Calculate the average number of employees for each industry
avg_employees_by_industry = companies_data.groupby('Industry')['employees'].mean()
avg_employees_by_industry
# Out:
# Industry
# 3D               250.900000
# AI               222.000000
# AdTech           119.000000
# Adtech           505.000000
# Advertising      391.000000
#                     ...
# Video            475.000000
# Warehousing      175.000000
# Wireless         193.800000
# eCommerce        519.800000
# eCommerceTech    440.866667
# Name: employees, Length: 120, dtype: float64

# %%
# Calculate the top 10 industries by average employees
top_avg_employees = avg_employees_by_industry.sort_values(ascending=False).head(10)
top_avg_employees
# Out:
# Industry
# Cybersecurity                                   957.0
# Pharmaceuticals                                 874.0
# NoCode/LowCode                                  870.0
# Networking                                      811.0
# DeliveryTech                                    774.0
# Travel Arrangements                             765.0
# Packaging and Containers Manufacturing          744.0
# Oil and Gas                                     708.0
# Apparel                                         665.0
# Furniture and Home Furnishings Manufacturing    640.0
# Name: employees, dtype: float64

# %%
# Set up plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_avg_employees.values, y=top_avg_employees.index, palette='viridis')

# Add labels and title
plt.xlabel('Average Number of Employees')
plt.ylabel('Industry')
plt.title('Average Number of Employees for Top 10 Industries')

# Show the plot
plt.show()

# %%
# Check the distribution of founding years
founding_years_distribution = companies_data['founded'].value_counts()
founding_years_distribution
# Out:
# 2017.0    104
# 2016.0     92
# 2018.0     79
# 2015.0     76
# 2014.0     62
# 2013.0     52
# 2019.0     49
# 2020.0     43
# 2012.0     38
# 2011.0     28
# 2021.0     24
# 2009.0     21
# 2010.0     15
# 2008.0     11
# 2007.0     10
# 2006.0      9
# 2002.0      5
# 2004.0      5
# 1999.0      5
# 2001.0      4
# 1998.0      4
# 1997.0      4
# 2000.0      4
# 1988.0      3
# 2003.0      3
# 2005.0      3
# 1980.0      3
# 2022.0      3
# 1993.0      2
# 1991.0      2
# 1985.0      2
# 1989.0      2
# 1854.0      1
# 1992.0      1
# 1915.0      1
# 1984.0      1
# 1946.0      1
# 1969.0      1
# 1973.0      1
# 1959.0      1
# 1990.0      1
# 1955.0      1
# 1949.0      1
# 1971.0      1
# 1976.0      1
# 1979.0      1
# 1888.0      1
# 1956.0      1
# 1963.0      1
# 1995.0      1
# 1994.0      1
# 1947.0      1
# 1978.0      1
# 1981.0      1
# 1982.0      1
# 1952.0      1
# Name: founded, dtype: int64

# %%
# Set up plot
plt.figure(figsize=(10, 6))
plt.hist(companies_data['founded'], bins=20, edgecolor='k', alpha=0.7)

# Add labels and title
plt.xlabel('Founding Year')
plt.ylabel('Number of Companies')
plt.title('Distribution of Companies\' Founding Years')

# Show the plot
plt.show()

# %%
# Calculate the average estimated revenues for each industry
avg_revenues_by_industry = companies_data.groupby('Industry')['estimated_revenues'].mean()
avg_revenues_by_industry
# Out:
# Industry
# 3D                58912460.0
# AI                38053925.0
# AdTech            20000000.0
# Adtech           107797600.0
# Advertising              NaN
#                     ...
# Video             74048000.0
# Warehousing              NaN
# Wireless          79093000.0
# eCommerce        116530200.0
# eCommerceTech     74455920.0
# Name: estimated_revenues, Length: 120, dtype: float64

# %%
# Calculate the top 10 industries by median estimated revenues
top_revenues_by_industry = companies_data.groupby('Industry')['estimated_revenues'].median().sort_values(ascending=False).head(10)
top_revenues_by_industry
# Out:
# Industry
# Machinery          3.110000e+09
# Materials          1.080000e+09
# Hospital/Health    7.500000e+08
# Networking         3.655080e+08
# Printing           3.000000e+08
# DeliveryTech       2.870000e+08
# Hospitality        2.640609e+08
# Apparel            2.595300e+08
# Retail             2.459772e+08
# Construction       2.436000e+08
# Name: estimated_revenues, dtype: float64

# %%
# Set up plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Industry', y='estimated_revenues', data=companies_data[companies_data['Industry'].isin(top_revenues_by_industry.index)], palette='viridis')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Add labels and title
plt.xlabel('Industry')
plt.ylabel('Estimated Revenues')
plt.title('Estimated Revenues Variation Across Top 10 Industries')

# Show the plot
plt.show()
