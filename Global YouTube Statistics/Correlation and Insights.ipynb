# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
data = pd.read_csv("data/Global YouTube Statistics.csv", encoding='latin1')

# %%
# Calculate the correlation between subscribers and video views
correlation = data['subscribers'].corr(data['video views'])
correlation
# Out:
# 0.7509576173780217

# %%
# Create a scatter plot to visualize the correlation
plt.figure(figsize=(8, 6))
sns.scatterplot(x='subscribers', y='video views', data=data, color='blue')
plt.title(f'Correlation between Subscribers and Video Views: {correlation:.2f}')
plt.xlabel('Number of Subscribers')
plt.ylabel('Total Video Views')
plt.tight_layout()
plt.show()

# %%
# Calculate the correlation between subscribers and highest estimated yearly earnings
correlation = data['subscribers'].corr(data['highest_yearly_earnings'])
correlation
# Out:
# 0.38893489579709606

# %%
# Create a scatter plot to visualize the correlation
plt.figure(figsize=(8, 6))
sns.scatterplot(x='subscribers', y='highest_yearly_earnings', data=data, color='green')
plt.title(f'Correlation between Subscribers and Highest Estimated Yearly Earnings: {correlation:.2f}')
plt.xlabel('Number of Subscribers')
plt.ylabel('Highest Estimated Yearly Earnings')
plt.tight_layout()
plt.show()

# %%
# Calculate the correlation between unemployment rate and number of subscribers
correlation = data['Unemployment rate'].corr(data['subscribers'])
correlation
# Out:
# -0.008251263861739766

# %%
# Create a scatter plot to visualize the correlation
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Unemployment rate', y='subscribers', data=data, color='purple')
plt.title(f'Correlation between Unemployment Rate and Subscribers: {correlation:.2f}')
plt.xlabel('Unemployment Rate')
plt.ylabel('Number of Subscribers')
plt.tight_layout()
plt.show()

# %%
# Calculate the correlation between urban population percentages and subscribers
correlation = data['Urban_population'].corr(data['subscribers'])
correlation
# Out:
# 0.08352096325348361

# %%
# Create a scatter plot to visualize the correlation
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Urban_population', y='subscribers', data=data, color='orange')
plt.title(f'Correlation between Urban Population Percentage and Subscribers: {correlation:.2f}')
plt.xlabel('Urban Population Percentage')
plt.ylabel('Number of Subscribers')
plt.tight_layout()
plt.show()

# %%
# Calculate the correlation between tertiary education enrollment percentages and subscribers
correlation = data['Gross tertiary education enrollment (%)'].corr(data['subscribers'])
correlation
# Out:
# -0.006803520246874561

# %%
# Create a scatter plot to visualize the correlation
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Gross tertiary education enrollment (%)', y='subscribers', data=data, color='yellow')
plt.title(f'Correlation between Tertiary Education Enrollment and Subscribers: {correlation:.2f}')
plt.xlabel('Gross Tertiary Education Enrollment (%)')
plt.ylabel('Number of Subscribers')
plt.tight_layout()
plt.show()
